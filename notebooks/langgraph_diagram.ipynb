# %% [markdown]
# # LangGraph Diagram
#
# This notebook visualizes the `TriageRouter` LangGraph.

# %%
from pathlib import Path
import sys

ROOT = Path('/Users/krzysztof/Documents/Accolade')
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# %%
from accolade_med_assistant.triage.triage_router import TriageRouter

router = TriageRouter()
graph_view = router.graph.get_graph()
graph_view

# %%
from IPython.display import Image, Markdown, display

# Prefer PNG rendering when supported.
try:
    png_bytes = graph_view.draw_mermaid_png()
    display(Image(png_bytes))
except Exception as exc:
    print(f'PNG rendering unavailable: {exc}')
    mermaid = graph_view.draw_mermaid()
    display(Markdown('```mermaid\n' + mermaid + '\n```'))
